# %% [markdown]
# <a href="https://colab.research.google.com/github/Yu0323/Data-analysis/blob/main/%E3%83%86%E3%82%B9%E3%83%88%E3%81%AE%E7%82%B9%E6%95%B0%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6%E3%81%AE%E6%9E%B6%E7%A9%BA%E3%81%AE%E3%83%87%E3%83%BC%E3%82%BF%E3%82%BB%E3%83%83%E3%83%88%E3%82%92%E7%94%A8%E3%81%84%E3%81%9F%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install japanize-matplotlib
import japanize_matplotlib
import os
import re
from datetime import datetime as dt
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/My Drive/Colab Notebooks')

# %%
df = pd.read_csv('生徒のスコアデータ.csv',header= None)
# https://www.kaggle.com/datasets/desalegngeb/students-exam-scores からダウンロードしたデータの名前を変更した

# %%
df
#データセットを表示
# Out:
#           0       1            2                   3             4   \
# 0        NaN  Gender  EthnicGroup          ParentEduc     LunchType
# 1        0.0  female          NaN   bachelor's degree      standard
# 2        1.0  female      group C        some college      standard
# 3        2.0  female      group B     master's degree      standard
# 4        3.0    male      group A  associate's degree  free/reduced
# ...      ...     ...          ...                 ...           ...
# 30637  816.0  female      group D         high school      standard
# 30638  890.0    male      group E         high school      standard
# 30639  911.0  female          NaN         high school  free/reduced
# 30640  934.0  female      group D  associate's degree      standard
# 30641  960.0    male      group B        some college      standard
#
#               5                    6              7             8   \
# 0       TestPrep  ParentMaritalStatus  PracticeSport  IsFirstChild
# ...

# %%
df = df.drop([0], axis=1)
#IDカラムを削除→このデータセットではインデックスで指定

# %%
df = df.rename(columns = {1: '性別',2: '民族',3:'両親の学歴',4:'ランチの種類',5:'テスト対策コースへの取り組み',6:'親の婚姻状況',7:'スポーツへの取り組み',8:'最初の子供か',8:'兄弟の人数',10:'通学手段',11:'週当たりの勉強時間',12:'数学のテストの点数',13:'リーディングテストの点数',14:'ライティングテストの点数' })
#カラム名を日本語に変更

# %%
df = df.drop(index=0)
#0行目の削除

# %%
df.info()
#欠損データの確認
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 1 to 30641
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   性別              30641 non-null  object
#  1   民族              28801 non-null  object
#  2   両親の学歴           28796 non-null  object
#  3   ランチの種類          30641 non-null  object
#  4   テスト対策コースへの取り組み  28811 non-null  object
#  5   親の婚姻状況          29451 non-null  object
#  6   スポーツへの取り組み      30010 non-null  object
#  7   兄弟の人数           29737 non-null  object
#  8   9               29069 non-null  object
#  9   通学手段            27507 non-null  object
#  10  週当たりの勉強時間       29686 non-null  object
#  11  数学のテストの点数       30641 non-null  object
#  12  リーディングテストの点数    30641 non-null  object
#  13  ライティングテストの点数    30641 non-null  object
# dtypes: object(14)
# memory usage: 3.3+ MB
